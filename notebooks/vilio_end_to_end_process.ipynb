# %% [markdown]
# **This notebook combines running training, inference & ensembling for the  models. For more information about Vilio, you could go to this [link](https://github.com/Muennighoff/vilio) which is going to the master repo for the used models.**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/

# %%
import torch
torch.cuda.get_device_name(0)

# %% [markdown]
# # Run Vilio Models

# %%
# Install PaddlePaddle Requirements
# !cd /content/drive/MyDrive/vilio/ernie-vil; pip install -r requirements.txt

# %%
# ES
# !cd /content/drive/MyDrive/vilio/ernie-vil; bash bash/training/ES/hm_ES.sh

# %%
# EL
# !cd /content/drive/MyDrive/vilio/ernie-vil; bash bash/training/EL/hm_EL.sh

# %% [markdown]
# **Optimised model**

# %%
# EL
# !cd /content/drive/MyDrive/vilio/ernie-vil; bash bash/training/EL/hm_EL.sh

# %% [markdown]
# # Combine & Output

# %%
# Reinstall requirements
# !cd /content/drive/MyDrive/vilio; pip install -r requirements.txt

# %%
# !cp -r /content/drive/MyDrive/vilio/ernie-vil/data/hm/ES*/*.csv /content/drive/MyDrive//vilio/data
# !cp -r /content/drive/MyDrive/vilio/ernie-vil/data/hm/EL*/*.csv /content/drive/MyDrive//vilio/data

# %%
# !cp -r ../vilio/ernie-vil/data/hm/ES*/*.csv /content/drive/MyDrive//vilio/data
# !cp -r /content/drive/MyDrive/vilio/ernie-vil/data/hm/ES365072/*.csv /content/drive/MyDrive//vilio/data

# %%
# !cd /content/drive/MyDrive/vilio; bash bash/hm_ens.sh

# %%
# Save final csvs
# !cp -r /content/drive/MyDrive/vilio/data/FIN*.csv ./
